# %% [markdown]
# ## Data Pipeline
# ---

# %%
import time
import pandas as pd
start_time = time.time()

# %%
# # Load EDGAR files
# import pickle

# df = pd.read_csv('datasets/table_companies_short.csv',sep=',', index_col=0)
# tickers = list(df['ticker'])
# df.head()

# import lxml.html.clean 
# data_dict = {}
# for i, t in enumerate(tickers):
#     with open("reports/" + t + ".txt", "rb") as file:
#         data_dict[t] = lxml.html.clean.clean_html(pickle.load(file))

# %%
files = !ls AnnualReports/*.txt

# %%
#files = files[0:60]

# %%
# Load ANNUAL REPORTS files


import lxml.html.clean 
data_dict = {}
for i, t in enumerate(files):
    with open(t , "r") as file:
        data_dict[t] = lxml.html.clean.clean_html(file.read())

# %%
#data_dict[files[0]]

# %%
# Financial stopwords
from nltk.corpus import stopwords

english_stop_words = stopwords.words('english')
stopwordsfile = "dictionaries/financial_stopwrods.txt"
file = open(stopwordsfile, "r")
financial_stop_words = file.read().split('\n')
stopwords = []
stopwords.extend(english_stop_words)
stopwords.extend(financial_stop_words)
stopwords = list(set(stopwords))

# %%
#print(data_dict['AXLX'][0:600])
#print(data_dict[files[0]])

# %%
# Data cleaning process
from text_cleaning import *

data_dict = clean_data_dict(data_dict, stopwords)

# %%
# Dict to pandas
data = pd.DataFrame\
    .from_dict({k: [v] for k, v in data_dict.items()})\
    .transpose()\
    .sort_index()\
    .rename(columns = {0:'report'})

# %%
# Calculate text scores and financial sentiment
from sentiment_scores import *

positive_words = read_dictionary('dictionaries/positive_words.txt')
negative_words = read_dictionary('dictionaries/negative_words.txt')
uncertainty_dict = read_dictionary('dictionaries/uncertainty_dictionary.txt')
constraining_dict = read_dictionary('dictionaries/constraining_dictionary.txt')

# %%
# Similarity to Gold standard
from nltk.tokenize import word_tokenize, sent_tokenize

gold_standard = 'AnnualReports/ABN_AMRO_Group_(2018).pdf.txt'
#gold_standard = 'AnnualReportsTest/ABN_AMRO_Group_(2018).pdf.txt'
gold_standard_tokens = word_tokenize(data_dict[gold_standard])

data['cosine_similarity'] = calculate_cosine(data_dict, gold_standard_tokens)
data['entropy_similarity'] = calculate_entropy(data_dict, gold_standard_tokens)

# %%
# Absolute scores
data['count_tokens'] = data.report.apply(total_word_count)
data['unique_tokens'] = [data.loc[i].to_numpy().nonzero()[0].size for i in data.index]
data['percentage_complex_word'] = data.report.apply(percentage_complex_word)
data['positive_score'] = data.report.apply(lambda x: generate_score(x, positive_words))
data['negative_score'] = data.report.apply(lambda x: generate_score(x, negative_words))
data['uncertainty_score'] = data.report.apply(lambda x: generate_score(x, uncertainty_dict))
data['constraining_score'] = data.report.apply(lambda x: generate_score(x, constraining_dict))

# %%
# Relative scores
data['prop_of_average'] = [round(i/data.count_tokens.mean(),2) for i in data.count_tokens]
data['relative_unique'] = [relative_score(x, y)*10 for x, y in zip(data.unique_tokens, data.count_tokens)]
data['relative_positive'] = [relative_score(x, y)*10 for x, y in zip(data.positive_score, data.count_tokens)]
data['relative_negative'] = [relative_score(x, y)*10 for x, y in zip(data.negative_score, data.count_tokens)]
data['relative_uncertainty'] = [relative_score(x, y)*10 for x, y in zip(data.uncertainty_score, data.count_tokens)]
data['relative_constraining'] = [relative_score(x, y)*10 for x, y in zip(data.constraining_score, data.count_tokens)]
data['fog_index'] = [calculate_fog_index(x, y) for x, y in zip(data.count_tokens, data.percentage_complex_word)]
data['distance_average'] = [round(i/data.count_tokens.mean(),2) for i in data.count_tokens]

# %%
# Keywords scores
from flashtext import KeywordProcessor

kp_risk_words = KeywordProcessor()
kp_risk_words.add_keywords_from_list(["risk", "loss"])
data['risk_loss'] = [len(kp_risk_words.extract_keywords(data.loc[i,'report'])) for i in data.index]
data['relative_risk'] = [relative_score(x, y)*100 for x, y in zip(data.risk_loss, data.count_tokens)]

kp_clean_words = KeywordProcessor()
kp_clean_words.add_keywords_from_list(["responsibility", "green energy", "renewable"])
data['green_words'] = [len(kp_clean_words.extract_keywords(data.loc[i,'report'])) for i in data.index]
data['relative_green'] = [relative_score(x, y)*100 for x, y in zip(data.green_words, data.count_tokens)]

# %%
data.head()
# Out:
#                                                                                          report  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt   abn amro bank abn amro ntable contents nabout ...
# AnnualReports/AGNC_Investment_(2018).pdf.txt  providing private capital housing market ninve...
# AnnualReports/A_G_Barr_(2018).pdf.txt         barr nannual accounts njanuary bru ninnovation...
# AnnualReports/Aboitiz_Power_(2018).pdf.txt    scanned camscanner sheet full name registratio...
# AnnualReports/Acer_(2018).pdf.txt             acer incorported npublication date april name ...
#
#                                               cosine_similarity  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                 0.0
# AnnualReports/AGNC_Investment_(2018).pdf.txt                0.0
# AnnualReports/A_G_Barr_(2018).pdf.txt                       0.0
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                  0.0
# AnnualReports/Acer_(2018).pdf.txt                           0.0
#
#                                               entropy_similarity  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt             0.280923
# AnnualReports/AGNC_Investment_(2018).pdf.txt            0.280923
# AnnualReports/A_G_Barr_(2018).pdf.txt                   0.280923
# AnnualReports/Aboitiz_Power_(2018).pdf.txt              0.280923
# AnnualReports/Acer_(2018).pdf.txt                       0.280923
#
#                                               count_tokens  unique_tokens  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt          73443              3
# AnnualReports/AGNC_Investment_(2018).pdf.txt         30689              3
# AnnualReports/A_G_Barr_(2018).pdf.txt                31277              3
# AnnualReports/Aboitiz_Power_(2018).pdf.txt           39717              3
# AnnualReports/Acer_(2018).pdf.txt                    64150              3
#
#                                               percentage_complex_word  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                  0.289136
# AnnualReports/AGNC_Investment_(2018).pdf.txt                 0.255629
# AnnualReports/A_G_Barr_(2018).pdf.txt                        0.309109
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                   0.295188
# AnnualReports/Acer_(2018).pdf.txt                            0.299548
#
#                                               positive_score  negative_score  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt              340            1095
# AnnualReports/AGNC_Investment_(2018).pdf.txt             172             440
# AnnualReports/A_G_Barr_(2018).pdf.txt                    377             270
# AnnualReports/Aboitiz_Power_(2018).pdf.txt               111             238
# AnnualReports/Acer_(2018).pdf.txt                        472            1107
#
#                                               uncertainty_score  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                1476
# AnnualReports/AGNC_Investment_(2018).pdf.txt                789
# AnnualReports/A_G_Barr_(2018).pdf.txt                       338
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                  323
# AnnualReports/Acer_(2018).pdf.txt                           524
#
#                                               constraining_score  ...  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                  420  ...
# AnnualReports/AGNC_Investment_(2018).pdf.txt                 177  ...
# AnnualReports/A_G_Barr_(2018).pdf.txt                        162  ...
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                    91  ...
# AnnualReports/Acer_(2018).pdf.txt                            353  ...
#
#                                               relative_positive  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt               0.046
# AnnualReports/AGNC_Investment_(2018).pdf.txt              0.056
# AnnualReports/A_G_Barr_(2018).pdf.txt                     0.121
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                0.028
# AnnualReports/Acer_(2018).pdf.txt                         0.074
#
#                                               relative_negative  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt               0.149
# AnnualReports/AGNC_Investment_(2018).pdf.txt              0.143
# AnnualReports/A_G_Barr_(2018).pdf.txt                     0.086
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                0.060
# AnnualReports/Acer_(2018).pdf.txt                         0.173
#
#                                               relative_uncertainty  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                  0.201
# AnnualReports/AGNC_Investment_(2018).pdf.txt                 0.257
# AnnualReports/A_G_Barr_(2018).pdf.txt                        0.108
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                   0.081
# AnnualReports/Acer_(2018).pdf.txt                            0.082
#
#                                               relative_constraining  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt                   0.057
# AnnualReports/AGNC_Investment_(2018).pdf.txt                  0.058
# AnnualReports/A_G_Barr_(2018).pdf.txt                         0.052
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                    0.023
# AnnualReports/Acer_(2018).pdf.txt                             0.055
#
#                                               fog_index  distance_average  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt   29377.316              1.69
# AnnualReports/AGNC_Investment_(2018).pdf.txt  12275.702              0.71
# AnnualReports/A_G_Barr_(2018).pdf.txt         12510.924              0.72
# AnnualReports/Aboitiz_Power_(2018).pdf.txt    15886.918              0.91
# AnnualReports/Acer_(2018).pdf.txt             25660.120              1.48
#
#                                               risk_loss  relative_risk  \
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt        1243           1.69
# AnnualReports/AGNC_Investment_(2018).pdf.txt        319           1.04
# AnnualReports/A_G_Barr_(2018).pdf.txt               147           0.47
# AnnualReports/Aboitiz_Power_(2018).pdf.txt          113           0.28
# AnnualReports/Acer_(2018).pdf.txt                   767           1.20
#
#                                               green_words  relative_green
# AnnualReports/ABN_AMRO_Group_(2018).pdf.txt            21            0.03
# AnnualReports/AGNC_Investment_(2018).pdf.txt            4            0.01
# AnnualReports/A_G_Barr_(2018).pdf.txt                  15            0.05
# AnnualReports/Aboitiz_Power_(2018).pdf.txt             76            0.19
# AnnualReports/Acer_(2018).pdf.txt                      49            0.08
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = [8, 8]

for i, company in enumerate(data.index):
    x = round(data.relative_green.loc[company],2)
    y = - round(data.relative_uncertainty.loc[company],2)
    s = round(data.distance_average.loc[company],2)
    plt.scatter(x, y, color='#FF3844', alpha=.8, s=s*150)
    plt.text(x+0.001, y+0.001, data.index[i][14:-14], fontsize=8)
    
plt.title('Number of Risk-Loss Terms Used in Document per Thousand Words', fontsize=20)
plt.xlabel('Green mentions', fontsize=15)
plt.ylabel('Uncertanty mentions', fontsize=15)
#plt.savefig('risk_loss.png')
plt.show()

# %%
data.columns
# Out:
# Index(['report', 'cosine_similarity', 'entropy_similarity', 'count_tokens',
#        'unique_tokens', 'percentage_complex_word', 'positive_score',
#        'negative_score', 'uncertainty_score', 'constraining_score',
#        'prop_of_average', 'relative_unique', 'relative_positive',
#        'relative_negative', 'relative_uncertainty', 'relative_constraining',
#        'fog_index', 'distance_average', 'risk_loss', 'relative_risk',
#        'green_words', 'relative_green'],
#       dtype='object')

# %%
import seaborn as sns

features = ['cosine_similarity','entropy_similarity','relative_uncertainty','relative_risk','relative_green']
#sns.pairplot(data.drop(columns=['report']))
sns.pairplot(data[features])

# %%
data = data.sort_values(['relative_green','relative_positive','entropy_similarity'], ascending=False)

# %%
data['invest'] = [1 if i < data.relative_risk.median() else 0 for i in data.relative_uncertainty]

# %%
data.head()
# Out:
#                                                                                        report  \
# AnnualReports/Holmen_(2018).pdf.txt         forest npaperboard npaper nwood products nrene...
# AnnualReports/Corbion_(2018).pdf.txt        annual nkeep creating ncorbion contact ncontac...
# AnnualReports/Aboitiz_Power_(2018).pdf.txt  scanned camscanner sheet full name registratio...
# AnnualReports/DSM_(2018).pdf.txt            royal dsm integrated nannual glance nnutrition...
# AnnualReports/Compass_Group_(2018).pdf.txt  annual nfocus nperformance people purpose nas ...
#
#                                             cosine_similarity  \
# AnnualReports/Holmen_(2018).pdf.txt                       0.0
# AnnualReports/Corbion_(2018).pdf.txt                      0.0
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                0.0
# AnnualReports/DSM_(2018).pdf.txt                          0.0
# AnnualReports/Compass_Group_(2018).pdf.txt                0.0
#
#                                             entropy_similarity  count_tokens  \
# AnnualReports/Holmen_(2018).pdf.txt                   0.280923         26971
# AnnualReports/Corbion_(2018).pdf.txt                  0.280923         32753
# AnnualReports/Aboitiz_Power_(2018).pdf.txt            0.280923         39717
# AnnualReports/DSM_(2018).pdf.txt                      0.280923         67126
# AnnualReports/Compass_Group_(2018).pdf.txt            0.280923         54983
#
#                                             unique_tokens  \
# AnnualReports/Holmen_(2018).pdf.txt                     3
# AnnualReports/Corbion_(2018).pdf.txt                    3
# AnnualReports/Aboitiz_Power_(2018).pdf.txt              3
# AnnualReports/DSM_(2018).pdf.txt                        3
# AnnualReports/Compass_Group_(2018).pdf.txt              3
#
#                                             percentage_complex_word  \
# AnnualReports/Holmen_(2018).pdf.txt                        0.246042
# AnnualReports/Corbion_(2018).pdf.txt                       0.294935
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                 0.295188
# AnnualReports/DSM_(2018).pdf.txt                           0.264130
# AnnualReports/Compass_Group_(2018).pdf.txt                 0.291563
#
#                                             positive_score  negative_score  \
# AnnualReports/Holmen_(2018).pdf.txt                    239             344
# AnnualReports/Corbion_(2018).pdf.txt                   288             393
# AnnualReports/Aboitiz_Power_(2018).pdf.txt             111             238
# AnnualReports/DSM_(2018).pdf.txt                       637             623
# AnnualReports/Compass_Group_(2018).pdf.txt             552             391
#
#                                             uncertainty_score  \
# AnnualReports/Holmen_(2018).pdf.txt                       207
# AnnualReports/Corbion_(2018).pdf.txt                      336
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                323
# AnnualReports/DSM_(2018).pdf.txt                          576
# AnnualReports/Compass_Group_(2018).pdf.txt                479
#
#                                             constraining_score  ...  \
# AnnualReports/Holmen_(2018).pdf.txt                        112  ...
# AnnualReports/Corbion_(2018).pdf.txt                       196  ...
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                  91  ...
# AnnualReports/DSM_(2018).pdf.txt                           210  ...
# AnnualReports/Compass_Group_(2018).pdf.txt                 417  ...
#
#                                             relative_negative  \
# AnnualReports/Holmen_(2018).pdf.txt                     0.128
# AnnualReports/Corbion_(2018).pdf.txt                    0.120
# AnnualReports/Aboitiz_Power_(2018).pdf.txt              0.060
# AnnualReports/DSM_(2018).pdf.txt                        0.093
# AnnualReports/Compass_Group_(2018).pdf.txt              0.071
#
#                                             relative_uncertainty  \
# AnnualReports/Holmen_(2018).pdf.txt                        0.077
# AnnualReports/Corbion_(2018).pdf.txt                       0.103
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                 0.081
# AnnualReports/DSM_(2018).pdf.txt                           0.086
# AnnualReports/Compass_Group_(2018).pdf.txt                 0.087
#
#                                             relative_constraining  fog_index  \
# AnnualReports/Holmen_(2018).pdf.txt                         0.042  10788.498
# AnnualReports/Corbion_(2018).pdf.txt                        0.060  13101.318
# AnnualReports/Aboitiz_Power_(2018).pdf.txt                  0.023  15886.918
# AnnualReports/DSM_(2018).pdf.txt                            0.031  26850.506
# AnnualReports/Compass_Group_(2018).pdf.txt                  0.076  21993.317
#
#                                             distance_average  risk_loss  \
# AnnualReports/Holmen_(2018).pdf.txt                     0.62        166
# AnnualReports/Corbion_(2018).pdf.txt                    0.75        182
# AnnualReports/Aboitiz_Power_(2018).pdf.txt              0.91        113
# AnnualReports/DSM_(2018).pdf.txt                        1.54        322
# AnnualReports/Compass_Group_(2018).pdf.txt              1.26        177
#
#                                             relative_risk  green_words  \
# AnnualReports/Holmen_(2018).pdf.txt                  0.62           68
# AnnualReports/Corbion_(2018).pdf.txt                 0.56           80
# AnnualReports/Aboitiz_Power_(2018).pdf.txt           0.28           76
# AnnualReports/DSM_(2018).pdf.txt                     0.48           88
# AnnualReports/Compass_Group_(2018).pdf.txt           0.32           54
#
#                                             relative_green  invest
# AnnualReports/Holmen_(2018).pdf.txt                   0.25       1
# AnnualReports/Corbion_(2018).pdf.txt                  0.24       1
# AnnualReports/Aboitiz_Power_(2018).pdf.txt            0.19       1
# AnnualReports/DSM_(2018).pdf.txt                      0.13       1
# AnnualReports/Compass_Group_(2018).pdf.txt            0.10       1
#
# [5 rows x 23 columns]

# %%
data.drop(columns=['report']).to_csv('data_short.csv')

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas, xgboost, numpy, textblob, string

# %%
# Importing the dataset
X = data.loc[:, ['relative_green','relative_positive','entropy_similarity']].values
y = data.loc[:,'invest'].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.fit_transform(y_test)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_test, label_test):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_test)
    return metrics.accuracy_score(predictions, label_test)

# %%
accuracy = train_model(ensemble.RandomForestClassifier(), X_train, y_train, X_test, y_test)
print ("RF, Selected variables: {}".format(accuracy))
# Out:
# RF, Selected variables: 1.0
# /Users/pedrohserrano/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 439.59447503089905 seconds ---

# %%
# --- 88.29133796691895 seconds -- Testfolder
